# %%
import random

p1 = 0
p2 = 0
p3=  0

while True:
    input("Player 1's turn (Press Enter to roll the dice): ")
    player1_input = random.choice([1, 2, 3, 4, 5, 6])
    print(f"Player 1 rolled a {player1_input}")

    if p1 == 0:
        if player1_input == 6:
            p1 = 1
            print("Player 1 moved to position 1")
    else:
        p1 += player1_input

        if p1 == 4:  # ladder
            p1 = 12
            print('Player 1 climbed a ladder to position 12')
        elif p1 == 8:  # ladder
            p1 = 24
            print('Player 1 climbed a ladder to position 24')
        elif p1==20:    # ladder
            p1==60
            print("player 1 claimed a ladder to position 60")
        elif p1 == 15:  # snake
            p1 = 4
            print('Player 1 got bitten by a snake and moved to position 4')
        elif p1 == 19:  # snake
            p1 = 7
            print('Player 1 got bitten by a snake and moved to position 7')
        elif p1==32:
            p1=21
            print('player 1 got bitten by a snake and moved to  position 21 ')
        elif p1==53:
            p1=35
            print('player 1 got bitten by a snake and moved to  position 35 ')
        elif p1==71:
            p1=44
            print('player 1 got bitten by a snake and moved to  position 44 ')
        elif p1 == 99:  # snake
            p1 = 82
            print('Player 1 climbed a ladder to position 82')

    print("Player 1's current position:", p1)

    if p1 >= 100:
        print("Player 1 wins!")
        break

    input("Player 2's turn (Press Enter to roll the dice): ")
    player2_input = random.choice([1, 2, 3, 4, 5, 6])
    print(f"Player 2 rolled a {player2_input}")

    if p2 == 0:
        if player2_input == 6:
            p2 = 1
            print("Player 2 moved to position 1")
    else:
        p2 += player2_input

        if p2 == 4:  # ladder
            p2 = 12
            print('Player  climbed a ladder to position 12')
        elif p2 == 8:  # ladder
            p2 = 24
            print('Player 2 climbed a ladder to position 24')
        elif p2 ==20:    # ladder
            p2 ==60
            print("player 2 claimed a ladder to position 60")
        elif p2 == 15:  # snake
            p1 = 4
            print('Player 2 got bitten by a snake and moved to position 4')
        elif p1 == 19:  # snake
            p1 = 7
            print('Player 2 got bitten by a snake and moved to position 7')
        elif p1==32:
            p1=21
            print('player 2 got bitten by a snake and moved to  position 21 ')
        elif p1==53:
            p1=35
            print('player 2 got bitten by a snake and moved to  position 35 ')
        elif p1==71:
            p1=44
            print('player 2 got bitten by a snake and moved to  position 44 ')
        elif p1 == 99:  # snake
            p1 = 82
            print('Player 2 climbed a ladder to position 82')

    

        elif p2 == 99:  # snake
            p2 = 82
            print('Player 2 climbed a ladder to position 82')

    print("Player 2's current position:", p2)

    if p3 >= 100:
        print("Player 2 wins!")
        break
        
    input("Player 3's turn (Press Enter to roll the dice): ")
    player3_input = random.choice([1, 2, 3, 4, 5, 6])
    print(f"Player 3 rolled a {player3_input}")
    if p3 == 0:
        if player3_input == 6:
            p3 = 1
            print("Player 3 moved to position 1")
    else:
        p3 += player1_input

        if p3 == 4:  # ladder
            p3 = 12
            print('Player 3 climbed a ladder to position 12')
        elif p3 == 8:  # ladder
            p3 = 24
            print('Player 3 climbed a ladder to position 24')
        elif p3==20:    # ladder
            p3==60
            print("player 3 claimed a ladder to position 60")
        elif p3 == 15:  # snake
            p3 = 4
            print('Player 3 got bitten by a snake and moved to position 4')
        elif p3 == 19:  # snake
            p3 = 7
            print('Player 3 got bitten by a snake and moved to position 7')
        elif p3 ==32:
            p3 =21
            print('player 3 got bitten by a snake and moved to  position 21 ')
        elif p3 ==53:
            p3 =35
            print('player 3 got bitten by a snake and moved to  position 35 ')
        elif p3 ==71:
            p3 =44
            print('player 3 got bitten by a snake and moved to  position 44 ')
        elif p3  == 99:  # snake
            p3 = 82
            print('Player 3 climbed a ladder to position 82')

    print("Player 3's current position:", p3)
    if p3 >= 100:
        print("Player 3 wins!")
        break
# Out:
# Player 1's turn (Press Enter to roll the dice):
# Player 1 rolled a 5
# Player 1's current position: 0
# Player 2's turn (Press Enter to roll the dice):
# Player 2 rolled a 1
# Player 2's current position: 0
# Player 3's turn (Press Enter to roll the dice):
# Player 3 rolled a 6
# Player 3 moved to position 1
# Player 3's current position: 1
# Player 1's turn (Press Enter to roll the dice):
# Player 1 rolled a 6
# Player 1 moved to position 1
# Player 1's current position: 1
# Player 2's turn (Press Enter to roll the dice):
# Player 2 rolled a 3
# Player 2's current position: 0
# Player 3's turn (Press Enter to roll the dice):
# Player 3 rolled a 6
# Player 3's current position: 7
# Player 1's turn (Press Enter to roll the dice):
# Player 1 rolled a 4
# Player 1's current position: 5
# Player 2's turn (Press Enter to roll the dice):
# Player 2 rolled a 6
# Player 2 moved to position 1
# Player 2's current position: 1
# Player 3's turn (Press Enter to roll the dice):
# ...
